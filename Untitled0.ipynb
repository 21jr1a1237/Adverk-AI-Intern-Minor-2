# %%
import cv2
from google.colab.patches import cv2_imshow

# %%
# Extracting haar cascade files for Face detection
# !wget https://raw.githubusercontent.com/opencv/opencv/master/data/haarcascades/haarcascade_frontalface_default.xml
# Out:
# --2023-07-23 11:02:51--  https://raw.githubusercontent.com/opencv/opencv/master/data/haarcascades/haarcascade_frontalface_default.xml
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 930127 (908K) [text/plain]
# Saving to: ‘haarcascade_frontalface_default.xml.1’
#
# haarcascade_frontal 100%[===================>] 908.33K  --.-KB/s    in 0.02s
#
# 2023-07-23 11:02:52 (49.7 MB/s) - ‘haarcascade_frontalface_default.xml.1’ saved [930127/930127]

# %% [markdown]
# # "Face" Detection

# %%
image=cv2.imread('/content/1000_F_140938459_ww2AxL7xhan4ozjdC7wUxYfYnpdsuqVg.jpg')
model=cv2.CascadeClassifier('/content/haarcascade_frontalface_default.xml')
Faces=model.detectMultiScale(image,1.1,5)
for(x,y,w,h) in Faces:
  cv2.rectangle(image,(x,y),(x+w,y+h),(0,0,255),2)
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=1000x667 at 0x7B4D9BF184C0>

# %%
# Loading an image
# !wget https://as1.ftcdn.net/v2/jpg/01/40/93/84/1000_F_140938459_ww2AxL7xhan4ozjdC7wUxYfYnpdsuqVg.jpg p1.jpg
# Out:
# --2023-07-23 11:02:52--  https://as1.ftcdn.net/v2/jpg/01/40/93/84/1000_F_140938459_ww2AxL7xhan4ozjdC7wUxYfYnpdsuqVg.jpg
# Resolving as1.ftcdn.net (as1.ftcdn.net)... 151.101.1.167, 151.101.65.167, 151.101.129.167, ...
# Connecting to as1.ftcdn.net (as1.ftcdn.net)|151.101.1.167|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 209927 (205K) [image/jpeg]
# Saving to: ‘1000_F_140938459_ww2AxL7xhan4ozjdC7wUxYfYnpdsuqVg.jpg.1’
#
# 1000_F_140938459_ww 100%[===================>] 205.01K  --.-KB/s    in 0.009s
#
# 2023-07-23 11:02:52 (22.8 MB/s) - ‘1000_F_140938459_ww2AxL7xhan4ozjdC7wUxYfYnpdsuqVg.jpg.1’ saved [209927/209927]
#
# --2023-07-23 11:02:52--  http://p1.jpg/
# Resolving p1.jpg (p1.jpg)... failed: Name or service not known.
# wget: unable to resolve host address ‘p1.jpg’
# FINISHED --2023-07-23 11:02:52--
# Total wall clock time: 0.1s
# Downloaded: 1 files, 205K in 0.009s (22.8 MB/s)

# %%
# Extracting haar cascade files for Eye detection
# !wget https://raw.githubusercontent.com/opencv/opencv/master/data/haarcascades/haarcascade_eye.xml
# Out:
# --2023-07-23 11:02:52--  https://raw.githubusercontent.com/opencv/opencv/master/data/haarcascades/haarcascade_eye.xml
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 341406 (333K) [text/plain]
# Saving to: ‘haarcascade_eye.xml.1’
#
# haarcascade_eye.xml 100%[===================>] 333.40K  --.-KB/s    in 0.02s
#
# 2023-07-23 11:02:53 (14.9 MB/s) - ‘haarcascade_eye.xml.1’ saved [341406/341406]

# %% [markdown]
# # "Eye" Detection

# %%
image=cv2.imread('/content/1000_F_140938459_ww2AxL7xhan4ozjdC7wUxYfYnpdsuqVg.jpg')
model=cv2.CascadeClassifier('/content/haarcascade_eye.xml')
Eye=model.detectMultiScale(image,1.12,7)
for(x,y,w,h) in Eye:
  cv2.rectangle(image,(x,y),(x+w,y+h),(0,0,255),2)
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=1000x667 at 0x7B4D9BF18700>

# %%
# Extracting haar cascade files for Smile detection
# !wget https://raw.githubusercontent.com/opencv/opencv/master/data/haarcascades/haarcascade_smile.xml
# Out:
# --2023-07-23 11:02:53--  https://raw.githubusercontent.com/opencv/opencv/master/data/haarcascades/haarcascade_smile.xml
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 188506 (184K) [text/plain]
# Saving to: ‘haarcascade_smile.xml.1’
#
# haarcascade_smile.x 100%[===================>] 184.09K  --.-KB/s    in 0.008s
#
# 2023-07-23 11:02:53 (21.4 MB/s) - ‘haarcascade_smile.xml.1’ saved [188506/188506]

# %% [markdown]
# # "Smile" Detection

# %%
image=cv2.imread('/content/1000_F_140938459_ww2AxL7xhan4ozjdC7wUxYfYnpdsuqVg.jpg')
model=cv2.CascadeClassifier('/content/haarcascade_smile.xml')
Smile=model.detectMultiScale(image,1.12,65)
for(x,y,w,h) in Smile:
  cv2.rectangle(image,(x,y),(x+w,y+h),(0,0,255),2)
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=1000x667 at 0x7B4D9BF1B370>

# %%
# Loading the image
# !wget https://cdni.autocarindia.com/Utils/ImageResizer.ashx?n=https://cdni.autocarindia.com/ExtraImages/20180402113123_NumberPlate_Swift.jpg&w=700&q=90&c=1 p1.jpg
# Out:
# /bin/bash: line 1: p1.jpg: command not found
# --2023-07-23 11:02:54--  https://cdni.autocarindia.com/Utils/ImageResizer.ashx?n=https://cdni.autocarindia.com/ExtraImages/20180402113123_NumberPlate_Swift.jpg
# Resolving cdni.autocarindia.com (cdni.autocarindia.com)... 18.65.39.47, 18.65.39.120, 18.65.39.107, ...
# Connecting to cdni.autocarindia.com (cdni.autocarindia.com)|18.65.39.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 59295 (58K) [image/jpeg]
# Saving to: ‘ImageResizer.ashx?n=https:%2F%2Fcdni.autocarindia.com%2FExtraImages%2F20180402113123_NumberPlate_Swift.jpg.1’
#
# ImageResizer.ashx?n 100%[===================>]  57.91K  --.-KB/s    in 0.006s
#
# 2023-07-23 11:02:54 (9.25 MB/s) - ‘ImageResizer.ashx?n=https:%2F%2Fcdni.autocarindia.com%2FExtraImages%2F20180402113123_NumberPlate_Swift.jpg.1’ saved [59295/59295]

# %%
# Extracting haar cascade files for Number plate detection
# !wget https://raw.githubusercontent.com/opencv/opencv/master/data/haarcascades/haarcascade_license_plate_rus_16stages.xml
# Out:
# --2023-07-23 11:02:54--  https://raw.githubusercontent.com/opencv/opencv/master/data/haarcascades/haarcascade_license_plate_rus_16stages.xml
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 47775 (47K) [text/plain]
# Saving to: ‘haarcascade_license_plate_rus_16stages.xml.1’
#
# haarcascade_license 100%[===================>]  46.66K  --.-KB/s    in 0.003s
#
# 2023-07-23 11:02:55 (13.5 MB/s) - ‘haarcascade_license_plate_rus_16stages.xml.1’ saved [47775/47775]

# %% [markdown]
# # "Number plate" Dectection

# %%
image=cv2.imread('/content/ImageResizer.ashx?n=https:%2F%2Fcdni.autocarindia.com%2FExtraImages%2F20180402113123_NumberPlate_Swift.jpg')
model=cv2.CascadeClassifier('/content/haarcascade_license_plate_rus_16stages.xml')
Number_plate=model.detectMultiScale(image,1.11,1)
for(x,y,w,h) in Number_plate:
  cv2.rectangle(image,(x,y),(x+w,y+h),(0,255,0),2)
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=870x570 at 0x7B4D9BF1A3B0>

# %% [markdown]
# # *SUMMARIZATION*
#
#
# ---
#
#
# *Face Detection:*<br>
#
#   - The code loads an image of a group of business people and a pre-trained Haar Cascade model for frontal face detection.<br>
#   - It uses face_cascade.detectMultiScale() to detect faces in the image.<br>
#   - Rectangles are drawn around the detected faces using cv2.rectangle().<br>
#   - The original image with face rectangles is displayed using cv2_imshow().<br>
#
# ---
#
#
#
# *Eye Detection:*<br>
#
#   - The code loads another image of a group of business people and a pre-trained Haar Cascade model for eye detection.<br>
#   - It uses eye_cascade.detectMultiScale() to detect eyes in the image.<br>
#   - Rectangles are drawn around the detected eyes using cv2.rectangle().<br>
#   - The original image with eye rectangles is displayed using cv2_imshow().<br>
#
# ---
#
#
#
# *Smile Detection:*<br>
#
#   - The code loads the same image used for eye detection and a pre-trained Haar Cascade model for smile detection.<br>
#   - It uses smile_cascade.detectMultiScale() to detect smiles in the image.<br>
#   - Rectangles are drawn around the detected smiles using cv2.rectangle().<br>
#   - The original image with smile rectangles is displayed using cv2_imshow().<br>
#
# ---
#
#
#
# *Number Plate Detection:*<br>
#
#   - The code loads an image of a car's number plate and a pre-trained Haar Cascade model for license plate detection.<br>
#   - It uses NP_cascade.detectMultiScale() to detect the number plate in the image.<br>
#   - A rectangle is drawn around the detected number plate using cv2.rectangle().<br>
#   - The original image with the number plate rectangle is displayed using cv2_imshow().
